# %%
#importamos la libreria de opencv y matplotlib para poder visualizar la imagen correctamente
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#leemos la imagen, se necesita poner la r delante de la dirección para que no se confunda en la ruta 
img = cv2.imread(r'C:\Users\joano\Desktop\vision artificial juan olivan\imagenes\lena.jpg',0)#imagen es escala de grises

# %%
hist=cv2.calcHist([img],[0],None,[256],[0,255])#img,canal.mask,número de partes de division de histograma, rango

# %%
plt.hist(img.ravel(),256,[0,255])#graficamos el histograma, .ravel nos devuelve el formato plano de la imagen, el siguiente datoes cuantas partes se divide el histograma y el ultimo es el rango
plt.show()

# %%
#leemos la imagen, se necesita poner la r delante de la dirección para que no se confunda en la ruta 
img = cv2.imread(r'C:\Users\joano\Desktop\vision artificial juan olivan\imagenes\lena.jpg')#imagen es escala de grises

color=('b','g','r')
for i,col in enumerate(color):#recorremos la variable color usando un ciclo for y con la funcion enumarete obtendriamos cada espacio de la tupla enumerado se obtendria 0b 1g 2r
    print(i,col)
    hist=cv2.calcHist([img],[i],None,[256],[0,255])#calculamos el histograma para cada canal
    plt.plot(hist,color=col)#graficamos el histograma por color
    plt.xlim([0,256])

plt.show()
# Out:
# 0 b
# 1 g
# 2 r
